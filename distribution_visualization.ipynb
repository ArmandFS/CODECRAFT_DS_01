# %% [markdown]
# ### CodeCraft Infotech Data Science Task 1:
# ##### Name: Armand Faris A Surbakti
#
# In this data science project. I will be using the World Happiness Dataset to perform Exploratory Data Analysis and Data Visualization using a number of python libraries such as numpy, matplotlib, plotly, and pandas.
# Dataset Source: https://www.kaggle.com/code/gcmadhan/world-happiness-index-report

# %% [markdown]
# Let's start by importing libraries

# %%
import numpy as np
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load Dataset, and Inspect it.

# %%
df = pd.read_csv("world-happiness-report-2021.csv")
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
#describe the statistics
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %% [markdown]
# Before visualizing our data, we should check for null and missing values.

# %%
#check for missing values
print(df.isnull().sum())
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %% [markdown]
# Visualizations will be done using a few matplotlib and seaborn plots.

# %%
#visualize the ladder score using seaborn histogram
plt.figure(figsize=(14, 7))
sns.set_style("whitegrid")

sns.histplot(
    data=df,
    x='Ladder score',
    kde=True,  
    bins=50,  
    color='blue'
)

plt.title("Happiness Ladder Score Distribution", fontsize=20)
plt.xlabel("Happiness Score", fontsize=16)
plt.ylabel("Frequency", fontsize=16)
plt.grid(color='lightgray', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's now try plotting a bar plot to visualize the average ladder score.

# %%
#bar plot
plt.figure(figsize=(14, 7))

#categorical plot
df['Regional indicator'] = df['Regional indicator'].astype('category')
sns.barplot(data=df, x='Regional indicator', y='Ladder score', palette='viridis')
#plt.xticks('Average Ladder Score by Region', fontsize=16, color='darkblue')
plt.xticks(rotation=30, ha='right', fontsize=10)
plt.xlabel('Region', fontsize=16)
plt.ylabel('Average Happiness Score', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# (optional) I decided to create more plots and visualizations for the fun of it and here are some more plots

# %% [markdown]
# Box Plot

# %%
#gdp per capita per region in correlation to happiness
plt.figure(figsize=(14,7))
sns.boxplot(data=df, x='Regional indicator', y='Logged GDP per capita', palette='Set2')
plt.xticks(rotation=30, fontsize=10)
plt.title('GDP per Capita Distribution by Region', fontsize=16)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Logged GDP per capita', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here, I'm going to make a violin plot that will plot both the box plot and KDE, and makes it ideal to comapare distributions

# %%
#violin plot
plt.figure(figsize=(16,7))
sns.violinplot(data=df, x='Regional indicator', y='Healthy life expectancy',palette='viridis', split=True)
plt.xticks(rotation=45, fontsize=10)
plt.title('Life Expectancy Distribution by Region', fontsize=16, color='black')
plt.xlabel('Region', fontsize=14)
plt.ylabel('Healthy Life Expectancy', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, I'll be doing a Scatter plot. I'll be comparing the relationship between  the Logged GDP per Capita and the Ladder Score

# %%
#create a scatter plot
plt.figure(figsize=(14, 7))
sns.scatterplot(data=df, x='Logged GDP per capita', y='Ladder score', hue='Regional indicator', palette='tab10', s=100, alpha=1)
plt.title('Happiness vs GDP per Capita', fontsize=16, color='black')
plt.xlabel('Logged GDP per Capita', fontsize=14)
plt.ylabel('Happiness Score (Ladder)', fontsize=14)
plt.legend(title='Region', bbox_to_anchor=(1, 1), loc='upper left')
plt.grid(alpha=0.9)
plt.tight_layout()
plt.show()
